# %% [markdown]
# # **Matplotlib Week 08**

# %% [markdown]
# # **Mengenal Plot Lifecyle**

# %% [markdown]
# Dalam sesi ini kita akan mempelajari lifecycle dari proses plotting dengan Matplotlib

# %% [markdown]
# **Import Moduless**

# %%
# %matplotlib inline

# %% [markdown]
# import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np
#
# print(matplotlib.__version__)
# print(np.__version__)

# %% [markdown]
# **Sample Dataset**

# %% [markdown]
# - Membuat dataset menggunakan dictionary yang berisikan 10 buah data dan ditampung dalam variable data

# %%
data = {'Item A': 109438,
        'Item B': 103569,
        'Item C': 112214,
        'Item D': 112591,
        'Item E': 100934,
        'Item F': 103660,
        'Item G': 137351,
        'Item H': 123381,
        'Item I': 135841,
        'Item J': 104437}

data
# Out:
# {'Item A': 109438,
#  'Item B': 103569,
#  'Item C': 112214,
#  'Item D': 112591,
#  'Item E': 100934,
#  'Item F': 103660,
#  'Item G': 137351,
#  'Item H': 123381,
#  'Item I': 135841,
#  'Item J': 104437}

# %%
#Ekstrak keys dari dictionary dan tampung dalam suatu tuple dengan nama variable items
items = tuple(data.keys())
items
# Out:
# ('Item A',
#  'Item B',
#  'Item C',
#  'Item D',
#  'Item E',
#  'Item F',
#  'Item G',
#  'Item H',
#  'Item I',
#  'Item J')

# %%
#Ekstrak values dari dictionary dan tampung dalam suatu tuple dengan nama variable count 
count = tuple(data.values())
count
# Out:
# (109438,
#  103569,
#  112214,
#  112591,
#  100934,
#  103660,
#  137351,
#  123381,
#  135841,
#  104437)

# %% [markdown]
# **Simple Plot**

# %%
#Plotting dataset ke dalam bentuk bar secara horizontal menggunakan pendekatan 00 Style
fig, ax = plt.subplots()

ax.barh(items, count)

plt.show()

# %% [markdown]
# **Pengaturan Style**

# %% [markdown]
# - Untuk mengetahui style apa saja yang tersedia dari fungsi matplotlib kita bisa memanggil fungsi plt.style.available
# - Untuk menggunakan style yang diinginkan kita dapat memanggil fungsi plt.style.use().

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')

fig, ax = plt.subplots()
ax.barh(items, count)
plt.show()

# %% [markdown]
# **Pengaturan Tick Table**

# %% [markdown]
# - Untuk menangkap objects dari ticks label kita bisa memanggil ax.get_xticklabels()
# - Pemanggilan method tersebut digunakan untuk mendapatkan akses terhadap objek dari tick label yang berada pada sumbu x
# - Fungsi plt.setp() digunakan untuk mengatur properties; setp merupakan kependekan dari set properties
# - Parameter pertama fungsi plt.setp() digunakan untuk mendefinisikan objek yang mau kita atur properties-nya
# - Parameter selanjutnya bersifat opsional.

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

labels = ax.get_xticklabels()

#Set properties
plt.setp(labels,
         rotation=45,
         horizontalalignment='right')

plt.show()

# %% [markdown]
# **Pengaturan Format pada Ticker**

# %% [markdown]
# - Untuk melakukan format pada ticker kita perlu meng-import suatu module FuncFormatter dari matplotlib.ticker
# - Pertama, kita perlu membangun suatu objek FuncFormatter()
# - Kemudian, untuk menerapkan formatter pada sumbu x kita dapat memanggil fungsi ax.xaxis.set_major_formatter.

# %%
from matplotlib.ticker import FuncFormatter

# %%
#Memmbuat fungsi yang mengkonversi ribuan menjadi huruf 'k'
def ribuan(x, pos):
    return f'{int(x/1000)}K'

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

formatter = FuncFormatter(ribuan)
ax.xaxis.set_major_formatter(formatter)

ax.set(title='Contoh Plot', 
       xlabel='Jumlah', 
       ylabel='Items')

plt.show()

# %% [markdown]
# **Pengaturan label pada sumbu (axis) dan judul (title)**

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

ax.set(title='Contoh Plot', 
       xlabel='Jumlah', 
       ylabel='Items')

plt.show()

# %% [markdown]
# **Penambahan Garis (vertical/horizontal line) pada Plot**

# %% [markdown]
# - Fungsi ax.axvline() digunakan untuk memunculkan garis vertikal pada axes
# - Parameter pertama fungsi tersebut digunakan untuk menentukan posisi garisnya
# - Parameter kedua fungsi tersebut digunakan untuk mengatur line style
# - Parameter ketiga fungsi tersebut digunakan untuk mengganti warna garis

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

ax.axvline(np.mean(count), 
           ls='--', 
           color='r')

ax.set(title='Contoh Plot', 
       xlabel='Jumlah', 
       ylabel='Items')

plt.show()

# %% [markdown]
# **Menyimpan hasil plot ke dalam suatu file**

# %% [markdown]
# - Untuk melihat tipe file apa saja yang didukung oleh matplotlib kita bisa memanggil fungsi fig.canvas.get_supported_filetypes()
# - Untuk menyimpan filenya kita bisa menggunakan fungsi fig.savefig()
# - Parameter pertama yang harus disertakan adalah menentukan nama file
# - Parameter selanjutnya bersifat opsional, seperti tranparansi dan dpi
# - Hasil plot tersebut akan disimpan dalam directory yang sama dengan file ipynb ini

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

ax.axvline(np.mean(count),
           ls='--',
           color='r')

ax.set(title='Contoh Plot',
       xlabel='Jumlah',
       ylabel='Items')

fig.savefig('Sales.png',
            transparent=True,
            dpi=80)
